# %%
import pandas as pd
df = pd.read_csv('/content/second_hand_cars.csv')

# %%
print(df)
# Out:
#        Company Name Car Name   Variant Fuel Type     Tyre Condition  \
# 0     Maruti Suzuki    Cruze        EX       CNG  Needs Replacement
# 1               Kia   Seltos       RXE    Petrol                New
# 2               Kia   Accord       RXE    Petrol                New
# 3            Nissan   Seltos  Highline    Diesel               Used
# 4         Chevrolet     Kwid  Highline    Petrol               Used
# ...             ...      ...       ...       ...                ...
# 2495         Toyota  Elantra       RXE    Petrol                New
# 2496            Kia    Sunny        LE       CNG  Needs Replacement
# 2497         Nissan    Sunny       RXE    Diesel               Used
# 2498          Honda    Swift        XL       CNG  Needs Replacement
# 2499        Renault     Kwid        GT    Diesel  Needs Replacement
#
#       Make Year Owner Type Registration Number  Mileage   Price  \
# 0          2018     Second         84-436-5584    52798  759107
# ...

# %%
df
# Out:
#        Company Name Car Name   Variant Fuel Type     Tyre Condition  \
# 0     Maruti Suzuki    Cruze        EX       CNG  Needs Replacement
# 1               Kia   Seltos       RXE    Petrol                New
# 2               Kia   Accord       RXE    Petrol                New
# 3            Nissan   Seltos  Highline    Diesel               Used
# 4         Chevrolet     Kwid  Highline    Petrol               Used
# ...             ...      ...       ...       ...                ...
# 2495         Toyota  Elantra       RXE    Petrol                New
# 2496            Kia    Sunny        LE       CNG  Needs Replacement
# 2497         Nissan    Sunny       RXE    Diesel               Used
# 2498          Honda    Swift        XL       CNG  Needs Replacement
# 2499        Renault     Kwid        GT    Diesel  Needs Replacement
#
#       Make Year Owner Type Registration Number  Mileage   Price  \
# 0          2018     Second         84-436-5584    52798  759107
# ...

# %%
df.head()
# Out:
#     Company Name Car Name   Variant Fuel Type     Tyre Condition  Make Year  \
# 0  Maruti Suzuki    Cruze        EX       CNG  Needs Replacement       2018
# 1            Kia   Seltos       RXE    Petrol                New       2020
# 2            Kia   Accord       RXE    Petrol                New       2022
# 3         Nissan   Seltos  Highline    Diesel               Used       2024
# 4      Chevrolet     Kwid  Highline    Petrol               Used       2018
#
#   Owner Type Registration Number  Mileage   Price      Transmission Type  \
# 0     Second         84-436-5584    52798  759107                 Manual
# 1      Third         79-114-3166    43412  505071              Automatic
# 2     Second         41-358-3344    95219  635322  Automatic (Tiptronic)
# 3      Third         92-708-1763    70370  483152  Automatic (Tiptronic)
# 4     Second         76-154-5485    85852  712961  Automatic (Tiptronic)
#
#   Body Color              Service Record             Insurance  \
# ...

# %%
df.shape
# Out:
# (2500, 16)

# %%
df.columns
# Out:
# Index(['Company Name', 'Car Name', 'Variant', 'Fuel Type', 'Tyre Condition',
#        'Make Year', 'Owner Type', 'Registration Number', 'Mileage', 'Price',
#        'Transmission Type', 'Body Color', 'Service Record', 'Insurance',
#        'Registration Certificate', 'Accessories'],
#       dtype='object')

# %%
df['Price']
# Out:
# 0       759107
# 1       505071
# 2       635322
# 3       483152
# 4       712961
#          ...
# 2495    643581
# 2496    889661
# 2497    327520
# 2498    348921
# 2499    955324
# Name: Price, Length: 2500, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Select the 'Price' column
price_data = df['Price']

# Calculate mean, median, and mode
mean_price = price_data.mean()
median_price = price_data.median()
mode_price = price_data.mode()[0]  # Mode can have multiple values, we take the first one

# Print the calculated values
print(f"Mean Price: {mean_price}")
print(f"Median Price: {median_price}")
print(f"Mode Price: {mode_price}")

# Plotting the boxplot for the 'Price' column
plt.figure(figsize=(10, 6))
sns.boxplot(x=price_data)
plt.title('Boxplot of Car Prices')
plt.xlabel('Price')

# Add mean, median, and mode to the plot
plt.axvline(mean_price, color='r', linestyle='--', label=f'Mean: {mean_price:.2f}')
plt.axvline(median_price, color='g', linestyle='-', label=f'Median: {median_price:.2f}')
plt.axvline(mode_price, color='b', linestyle='-.', label=f'Mode: {mode_price:.2f}')
plt.legend()

plt.show()
# Out:
# Mean Price: 608120.8976
# Median Price: 612012.5
# Mode Price: 343654

# %%
price_data = df['Price']
# create a figure
plt.figure(figsize=(20, 5))
x = range(df['Price'].size)
y = df['Price']
plt.scatter(x, y, marker='x', s=0.5)
# also need to make the figure readable -- very important from stats perspective!
plt.title("Price of cars")
plt.xlabel("ID of cars")
plt.ylabel("Price")
plt.show()

# %%
# Select the 'Price' column
price_data = df['Price']

# Calculate mean and standard deviation
mean_price = price_data.mean()
std_dev_price = price_data.std()

# Print the calculated values
print(f"Mean Price: {mean_price}")
print(f"Standard Deviation: {std_dev_price}")

# Plotting the histogram for the 'Price' column
plt.figure(figsize=(10, 6))
sns.histplot(price_data.dropna(), bins=30, kde=False, color='skyblue', edgecolor='black')
plt.title('Histogram of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Add mean and standard deviation lines to the plot
plt.axvline(mean_price, color='r', linestyle='--', linewidth=2, label=f'Mean: {mean_price:.2f}')
plt.axvline(mean_price + std_dev_price, color='g', linestyle='--', linewidth=2, label=f'Mean + 1 SD: {mean_price + std_dev_price:.2f}')
plt.axvline(mean_price - std_dev_price, color='g', linestyle='--', linewidth=2, label=f'Mean - 1 SD: {mean_price - std_dev_price:.2f}')
plt.legend()

plt.show()
# Out:
# Mean Price: 608120.8976
# Standard Deviation: 231056.1267132967
